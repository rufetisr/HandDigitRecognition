# %%
#Inference script
# %pip install ultralytics
from ultralytics import YOLO

# Replace with best.pt
model = YOLO('/content/best.pt')


def run_inference(image_path):

    results = model.predict(source=image_path, imgsz=512)

    # Display results for each item in the results list
    for result in results:
       result.show()

# Test the script
image_path = 'your image file path'  # Replace with your image file path
results = run_inference(image_path)
# Out:
# ...
#
# image 1/1 /content/3.1.jpg: 512x384 3 fingers, 1 hand, 192.4ms
# Speed: 3.8ms preprocess, 192.4ms inference, 1.2ms postprocess per image at shape (1, 3, 512, 384)
# <PIL.Image.Image image mode=RGB size=960x1280>
